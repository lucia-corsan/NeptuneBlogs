# %% [markdown]
# # How to improve a prompt by evaluating metrics iteratively
# ### Lucía Cordero Sánchez

# %% [markdown]
# ## Step 1: Setup

# %%
# !pip install neptune==1.10.4
# !pip install torch==2.3.1
# !pip install textstat
# !pip install nltk==3.8.1
# !pip install openai==1.41.0
# Out:
# Requirement already satisfied: neptune in /usr/local/lib/python3.10/dist-packages (1.10.4)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.1.43)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from neptune) (9.4.0)
# Requirement already satisfied: PyJWT in /usr/local/lib/python3.10/dist-packages (from neptune) (2.8.0)
# Requirement already satisfied: boto3>=1.28.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.34.153)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (11.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (8.1.7)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.0.0)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from neptune) (24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neptune) (2.1.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from neptune) (5.9.5)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (2.31.0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.3.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.16.0)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (4.12.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from neptune) (2.0.7)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.8.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.153 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.28.0->neptune) (1.34.153)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.28.0->neptune) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.28.0->neptune) (0.10.2)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (6.1.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (1.0.8)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (6.0.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (3.19.2)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (1.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython>=2.0.8->neptune) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (2024.7.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from swagger-spec-validator>=2.7.4->neptune) (4.23.0)
# Requirement already satisfied: importlib-resources>=1.3 in /usr/local/lib/python3.10/dist-packages (from swagger-spec-validator>=2.7.4->neptune) (6.4.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune) (2024.1)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.10/dist-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (0.19.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (3.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (0.1.1)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (24.6.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (2.9.0.20240316)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 20.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105
# Collecting textstat
#   Downloading textstat-0.7.4-py3-none-any.whl.metadata (14 kB)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.16.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from textstat) (71.0.4)
# Downloading textstat-0.7.4-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.6 MB/s eta 0:00:00
# Downloading pyphen-0.16.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.1 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.16.0 textstat-0.7.4
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import neptune
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import textstat
import nltk
from nltk.tokenize import word_tokenize
import openai

# Check your dependencies' versions
neptune.__version__
torch.__version__
textstat.__version__
nltk.__version__
openai.__version__
# Out:
# '1.41.0'

# %%
# Initialize Neptune with your credentials
run = neptune.init_run(
    project="your_name",
    api_token="your_token",
)

client = OpenAI(
    # This is the default and can be omitted
    api_key="your_token",
)
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/lucia.corsan/Prompt-Engineering-Tutorial1/e/PROMPT-16

# %% [markdown]
# ## Step 2: Define metrics (qualitative)

# %%
# Load pre-trained model and tokenizer for perplexity calculation
model_name = 'gpt2'
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

def calculate_diversity(text):
    tokens = word_tokenize(text.lower())
    num_tokens = len(tokens)
    num_unique_tokens = len(set(tokens))
    diversity = num_unique_tokens / num_tokens if num_tokens > 0 else 0
    return diversity

def calculate_fluency(text):
    readability_score = textstat.flesch_reading_ease(text)
    return readability_score

def calculate_perplexity(text):
    tokens_tensor = tokenizer.encode(text, return_tensors='pt')
    with torch.no_grad():
        outputs = model(tokens_tensor, labels=tokens_tensor)
        loss = outputs.loss
        perplexity = torch.exp(loss).item()
    return perplexity

def generate_text(prompt, max_tokens):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        max_tokens=max_tokens,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

def evaluate_prompt(prompt, max_tokens):
    generated_text = generate_text(prompt, max_tokens)
    print(f"Generated Text: {generated_text}")

    metrics = {
    'diversity': calculate_diversity(generated_text),
    'fluency': calculate_fluency(generated_text),
    'perplexity': calculate_perplexity(generated_text),
    }
    return metrics

# %% [markdown]
# ## Step 3: Initial testing and logging

# %%
# Define the range of max_tokens to test
token_ranges = range(15, 200, 15)

results = []

for max_tokens in token_ranges:
    metrics = evaluate_prompt("Write a story about hero's journey. ", max_tokens)

    # Log metrics to neptune.ai
    run["metrics/diversity"].append(metrics['diversity'])
    run["metrics/fluency"].append(metrics['fluency'])
    run["metrics/perplexity"].append(metrics['perplexity'])
    run["max_tokens"].append(max_tokens)

# Finalize the experiment
run.stop()
# Out:
# Generated Text: Once upon a time, in a small village nestled among the mountains, there
# Generated Text: Once upon a time in the peaceful village of Oakwood, there lived a young farmer named Thomas. Thomas was known for his kindness, hard work,
# Generated Text: Once upon a time, in a small village nestled between majestic mountains and lush forests, there lived a young man named Leo. Leo had always dreamt of embarking on a great adventure, much like the heroes he had read
# Generated Text: Once upon a time in the quaint village of Willowbrook, there lived a young orphan named Marcus. Marcus had always dreamed of going on grand adventures and becoming a hero like the legendary warriors of old. One day, a mysterious visitor arrived in the village and revealed to Marcus that he was the chosen one
# Generated Text: Once upon a time, in a small village nestled at the foot of a mighty mountain, there lived a young orphan named Finn. Despite his humble upbringing, Finn possessed a kind heart and an adventurous spirit that set him apart from the other villagers.
#
# One day, a terrible storm descended upon the village, bringing with it floods and destruction. As the villagers struggled to survive, a
# Generated Text: Once upon a time, in the land of Aradon, there lived a young farmer named Erik. He spent his days tending to his crops and caring for his animals, but deep down he longed for something more. One night, as Erik gazed up at the stars, a shooting star streaked across the sky, and he felt a sudden sense of purpose stir within him.
#
# The next day, Erik set out on a journey to
# Generated Text: Once upon a time, in a peaceful village nestled between rolling green hills and a sparkling river, there lived a young farm boy named Lucas. Lucas was known for his kind heart and adventurous spirit, always dreaming of a life beyond the confines of his small village.
#
# One fateful day, a dark shadow fell over the village as a menacing dragon descended upon them, breathing fire and wreaking havoc. The villagers were paralyzed with fear, unable to defend themselves against this dreaded beast. Lucas, however, felt a surge of bravery within
# Generated Text: Once upon a time in a distant kingdom, a young farmer named Thomas woke up to find his village under attack by a fierce dragon. The dragon had been terrorizing the land for years, and the villagers lived in constant fear of its wrath. Thomas knew that he had to do something to save his home and his people.
#
# With a heavy heart and a determined spirit, Thomas set out on a journey to find a way to defeat the dragon. Along the way, he encountered many challenges and obstacles that tested his courage and resolve. He faced treacherous mountains, dark forests, and raging rivers,
# Generated Text: Once upon a time, in the mystical land of Elysium, there lived a young man named Aiden. Aiden was an ordinary farmer who dreamt of adventure and greatness, but he never imagined that his life was about to change forever.
#
# One fateful day, a group of dark creatures known as the Shadowbeasts attacked the village of Elysium, spreading fear and destruction wherever they went. Aiden watched in horror as his friends and family were taken captive by the evil beings.
#
# Feeling a surge of courage and determination within him, Aiden made a decision that would alter the course of his life. He vowed to rescue his loved ones and free his
# Generated Text: Once upon a time, in the land of Eldoria, there lived a young farm boy named Lucas. Lucas had always dreamt of adventures beyond the small village where he lived, but his daily tasks of tending to the crops and animals kept him grounded.
#
# One fateful day, a darkness descended upon Eldoria. A powerful sorcerer named Malakar had unleashed a horde of demons upon the land, causing chaos and destruction wherever they went. The village elder revealed to Lucas that he was the chosen one, destined to embark on a hero's journey to defeat Malakar and restore peace to Eldoria.
#
# With a heavy heart but unwavering determination, Lucas said farewell to his family and set out on his quest. Along the way
# Generated Text: Once upon a time, in the peaceful village of Serenity, there lived a young farmer named Oliver. Oliver had always dreamt of adventure, but he was content with his simple life tending to the crops and animals on his family's farm. However, one fateful night, a mysterious figure appeared in Oliver's dreams and beckoned him to embark on a journey that would change the course of his life forever.
#
# The next morning, Oliver woke with a sense of unease, unable to shake the vivid images from his dreams. As he went about his daily chores, a great storm suddenly descended upon the village, bringing chaos and destruction in its wake. Amidst the chaos, the mysterious figure from Oliver's dream appeared before him once more, revealing himself to be a wise old sage named Atlas.
#
# Atlas explained to Oliver
# Generated Text: Once upon a time, in a small village nestled among the rolling hills, there lived a young farmer named Owen. Owen had always dreamed of adventure beyond the fields and forests that surrounded his home. Little did he know that his destiny was about to change forever.
#
# One day, a wise old traveler arrived in the village, seeking assistance. He explained to the villagers that an ancient evil had begun to stir in the neighboring kingdom, threatening to spread darkness and chaos across the land. The traveler revealed that a chosen hero would need to embark on a perilous journey to retrieve a magical artifact that could defeat the evil once and for all.
#
# Feeling a sense of purpose and determination welling up inside him, Owen stepped forward and offered to take on the quest. The traveler smiled knowingly and handed him a map that showed the way to the artifact's location, deep within the Forbidden Forest.
#
# With the blessings of
# Generated Text: Once upon a time, in the humble village of Oakvale, there lived a young shepherd named Alex. Alex had always dreamt of grand adventures and had a yearning for something greater than tending to the sheep in the rolling green hills. Little did he know that his life was about to change forever.
#
# One stormy night, a mysterious old man visited the village and told of an ancient prophecy that foretold of a great evil threatening to engulf the land. According to the prophecy, a chosen hero would rise to stand against this darkness and bring peace to the realm.
#
# Drawn by destiny, Alex volunteered to take on the mantle of the hero and set out on a perilous journey across the vast and treacherous lands beyond Oakvale. Along the way, he encountered various challenges and obstacles that tested his courage, wisdom, and strength. He faced fearsome beasts, cunning bandits, and dark sorcerers who sought to thwart his quest.
#
# Through his
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 8 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 8 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lucia.corsan/Prompt-Engineering-Tutorial1/e/PROMPT-14/metadata

# %% [markdown]
# ## Step 4: Refine prompts based on results

# %%
new_prompt_1 = "Write a story about hero's journey. Write a short scene where the hero receives an urgent call to a life-changing mission, write a short scene that reveals the hero's internal conflict and how he overcomes it during his journey."

new_prompt_2 = "Write a story about hero's journey. Describe in a few lines the hero's world or environment before he begins his adventure."

# %% [markdown]
# ## Step 5: Reevaluate Refined Prompts and Log New Metrics

# %%
# REMINDER: Execute again the cell with your credentials before this one
# Define the range of max_tokens to test
token_ranges = range(15, 200, 15)

results = []

for max_tokens in token_ranges:
    metrics = evaluate_prompt(new_prompt_1, max_tokens)

    # Log metrics to neptune.ai
    run["metrics/diversity"].append(metrics['diversity'])
    run["metrics/fluency"].append(metrics['fluency'])
    run["metrics/perplexity"].append(metrics['perplexity'])
    run["max_tokens"].append(max_tokens)

# Finalize the experiment
run.stop()
# Out:
# Generated Text: Once upon a time, in the quaint village of Thornwood, there lived
# Generated Text: Once upon a time in the mystical land of Eldoria, there lived a humble blacksmith named Finn. Though Finn spent his days crafting swords and shields
# Generated Text: In the land of Ashenvale, there lived a young blacksmith named Aiden. His village had been plagued by a terrible curse that left the crops barren and the people ailing. One day, as Aiden hammered
# Generated Text: Once upon a time, in the village of Elloria, there lived a humble blacksmith named Aiden. Aiden was known for his kindness and skill in crafting weapons and armor for the villagers. Little did he know, his simple life was about to change forever.
#
# One evening, as Aiden
# Generated Text: Once upon a time, in the quaint village of Oakwood, there lived a young farmer named Thomas. Thomas harbored dreams of adventure and heroism, but the mundane responsibilities of tending to his family’s farm kept him bound to the monotony of everyday life. Little did Thomas know that his true calling was about to find him in the most unexpected way.
#
# One peaceful
# Generated Text: Once upon a time in the land of Ardenia, there lived a young farmer named Leo. Despite his humble beginnings, Leo carried a great sense of adventure within him, often daydreaming about epic quests and heroic deeds. Little did he know that his own hero's journey was about to unfold.
#
# One fateful evening, as Leo was tending to his crops under the starlit sky, a bright light shone down upon him. Start
# Generated Text: In the land of Eldoria, there existed a humble farmer named Finn. Finn had always dreamt of something greater than tending to his crops day in and day out. Little did he know, his life was about to take a most unexpected turn.
#
# One tranquil evening, as Finn sat by the warmth of his hearth, a mysterious figure cloaked in shadows appeared at his doorstep. Startled, Finn's heart raced as the figure revealed himself to be a wise old wizard named Elric. With urgency in his voice
# Generated Text: Once upon a time in the land of Aveloria, there lived a young man named Marcus. Marcus was known for his bravery and selflessness, always putting others before himself. One day, as he was walking through the bustling market square, a mysterious figure appeared before him, their face hidden beneath a hood.
#
# "Young warrior," the figure spoke in a voice that seemed to resonate within Marcus's soul, "A great evil threatens our land. You have been chosen to embark on a life-changing mission to defeat this darkness and restore peace to Aveloria."
#
# Marcus felt a surge of determination well
# Generated Text: Once upon a time, in the peaceful village of Eldoria, there lived a young man named Tristan. He was known for his bravery and kindness, and the villagers often sought his help in times of need.
#
# One day, as Tristan was tending to his fields, a sudden gust of wind blew through the village square, carrying with it a parchment that landed at his feet. Curious, he picked up the parchment and read the urgent call written in elegant script: "Brave soul, the fate of the kingdom rests in your hands. A great evil threatens to consume our land, and only you have the power to stop it. Journey to the Forbidden Mountains and retrieve
# Generated Text: Title: The Call of Destiny
#
# In the quiet town of Oakridge, a young man named Alex led a simple life as a blacksmith's apprentice. He spent his days hammering away at the forge, dreaming of a life beyond the village. Little did he know, his fate was about to take a dramatic turn.
#
# One evening, as the sun dipped below the horizon, a mysterious stranger arrived in Oakridge. The stranger had a grave expression on his face as he approached Alex.
#
# "You are the one destined to save our kingdom," the stranger declared, handing Alex a golden amulet inscribed with ancient symbols.
#
# Alex was taken aback, unsure of what to make of the stranger's words. But deep down, he felt a stirring sense
# Generated Text: Title: The Path of Redemption
#
# In a small village nestled between rugged mountains, a young man named Kael lived a quiet life as a skilled archer. But destiny had other plans for him. One stormy night, as lightning pierced the sky and thunder roared with fury, a mysterious figure appeared before Kael, his face obscured by shadows.
#
# "I come bearing a message of great urgency," the figure's voice boomed. "You have been chosen for a life-changing mission, one that will test your courage and strength. A darkness threatens to engulf this land, and only you can stop it."
#
# Kael felt a surge of fear and doubt coursing through his veins. Was he truly capable of facing such a formidable challenge? His heart raced as he grappled with his inner turmoil, the weight of self
# Generated Text: In a small village nestled by the mountains, a young shepherd named Eren lived a peaceful and unassuming life. Little did he know that destiny had a grand adventure in store for him. One chilly evening, as Eren tended to his flock under the starlit sky, a shimmering figure appeared before him. It was the wise old sage of the village, known for his prophetic visions.
#
# "Eren, a great peril looms over our land," the sage spoke gravely, his voice laced with urgency. "You have been chosen by the spirits to embark on a mission of utmost importance. The fate of our people rests in your hands."
#
# With a mix of fear and determination burning within him, Eren heeded the sage's words and set off on his journey. As he ventured through unknown lands, faced with treacherous obstacles and daunting challenges, doubts crept into his
# Generated Text: Once upon a time in the distant land of Eldoria, there was a humble blacksmith named Gareth who lived a quiet life in the village of Oakridge. Little did he know that his fate was about to change forever.
#
# One fateful evening, as Gareth was hammering away at a sword in his workshop, a mysterious figure cloaked in shadows appeared before him.
#
# "Gareth, I come bearing a message of great importance," the figure spoke with urgency. "The kingdom of Eldoria is under threat from the dark forces of the Wraith King. Only you possess the strength and courage to embark on this life-changing mission. Will you answer the call of your destiny?"
#
# Gareth's heart raced as he considered the gravity of the situation. He had always dreamed of embarking on a grand adventure, but the thought of leaving his home and loved ones behind filled him with fear and doubt. However, deep down, he knew that this was his moment to prove himself
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 4 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 4 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lucia.corsan/Prompt-Engineering-Tutorial1/e/PROMPT-15/metadata

# %%
# Define the range of max_tokens to test
token_ranges = range(15, 200, 15)

results = []

for max_tokens in token_ranges:
    metrics = evaluate_prompt(new_prompt_2, max_tokens)

    # Log metrics to neptune.ai
    run["metrics/diversity"].append(metrics['diversity'])
    run["metrics/fluency"].append(metrics['fluency'])
    run["metrics/perplexity"].append(metrics['perplexity'])
    run["max_tokens"].append(max_tokens)

# Finalize the experiment
run.stop()
# Out:
# Generated Text: Once upon a time in the peaceful kingdom of Serenia, lived a young
# Generated Text: In the peaceful kingdom of Veridian, there lived a humble blacksmith named Aiden. Surrounded by rolling meadows and towering mountains, Veridian
# Generated Text: Once upon a time in the peaceful kingdom of Eldoria, there lived a young farmer named Marcus. He spent his days tending to his crop fields and helping his village prosper under the guidance of the wise King Elric.
# Generated Text: Once upon a time, in the peaceful village of Evergreen Valley, lived a young farmer named Ethan. His world was one of routine and simplicity, waking up at dawn to tend to the crops, surrounded by the lush green fields and the gentle sounds of nature. Ethan was content with his life,
# Generated Text: In the peaceful kingdom of Elysia, nestled between majestic mountains and shimmering lakes, lived a young blacksmith named Alex. He spent his days crafting swords and armor, surrounded by the laughter of children playing in the village square and the scent of fresh baked bread wafting from the nearby bakery. Life was simple and serene in Elysia, but Alex felt a
# Generated Text: In the land of Eldoria, peace reigned for centuries under the wise rule of King Alaric. The kingdom was prosperous, with lush forests, sparkling rivers, and towering castles symbolizing its grandeur. But lurking on the horizon was a growing darkness, as whispers spread of an ancient evil stirring in the shadows, threatening to plunge Eldoria into chaos. In this idyllic world, our hero, a young farmer named Finn,
# Generated Text: In the quaint village of Oakridge, nestled between lush green forests and towering mountains, lived a young blacksmith named Lucas. The villagers knew him for his skilled craftsmanship and kind heart. Lucas spent his days forging swords and armor, content with his simple life and the routine of the village.
#
# However, everything changed one fateful day when a powerful dragon descended upon Oakridge, wreaking havoc and spreading fear among the villagers. As homes burned and cries filled the air, Lucas knew he had to step up and face the creature
# Generated Text: In the peaceful kingdom of Eldoria, situated amidst lush forests and crystal-clear rivers, lived a humble blacksmith named Aiden. The townspeople adored him for his kindness and exceptional skill in crafting one-of-a-kind weapons and armor.
#
# Aiden's world was harmonious, filled with the comforting clang of his hammer against the anvil and the laughter of children playing in the streets. But unbeknownst to him, a dark shadow loomed on the horizon, threatening the very existence of Eldoria.
#
# One fateful night, a mysterious visitor arrived at Aiden's doorstep, revealing a
# Generated Text: Once upon a time in the land of Verdantia, a kingdom shrouded in the lush greenery of its enchanted forests and mystical mountains, lived a humble blacksmith named Aiden. Aiden spent his days toiling over the blazing forge, crafting swords and armor for the knights who protected the realm.
#
# Despite the beauty of Verdantia, a darkness loomed on the horizon - a powerful sorcerer, Malakar, had risen to power and unleashed his malevolent magic upon the land. The once peaceful kingdom was now plagued by monsters and despair, as fear gripped the hearts of its people.
#
# Feeling the weight of the suffering around him, A
# Generated Text: Once upon a time, in a small village nestled between rolling hills and lush forests, lived a young blacksmith named Finn. The village was a peaceful place, its inhabitants going about their daily lives with contentment and routine. Finn, though skilled at his craft, yearned for something more, a longing that whispered to him of adventures beyond the horizon and mysteries waiting to be unraveled.
#
# Despite the warmth of the village and the love of his family, Finn felt a restlessness stirring within him, a call to seek out the unknown and test his mettle against the challenges that lay beyond the village's borders. Little did he know that the path he was about to embark upon would lead him on a journey of self-discovery, courage, and
# Generated Text: Once upon a time in the peaceful village of Eldoria, nestled between rolling hills and lush forests, lived a young blacksmith named Aiden. The villagers knew him as a kind-hearted soul, skilled in his craft and always willing to lend a hand to those in need. Life in Eldoria was simple and harmonious, with everyone living in a close-knit community where traditions were upheld and peace reigned supreme.
#
# Despite the tranquility of his surroundings, Aiden felt a restless stirring in his heart, a yearning for something greater than his routine life of forging swords and repairing plows. Little did he know that this longing would set him on a path that would take him far beyond the familiar borders of Eldoria, into a realm of mystic realms and ancient prophecies, where he would uncover his true
# Generated Text: Once upon a time, in the peaceful village of Greenridge, there lived a humble blacksmith named Aiden. Greenridge was a quaint, idyllic town surrounded by lush forests and rolling hills. Aiden was content with his simple life, forging tools for his fellow villagers and spending evenings at the local tavern sharing laughter and stories with friends. However, deep down, Aiden yearned for something more, feeling a restlessness stirring within him that he couldn't explain. Little did he know that his world was about to change forever as he embarked on a hero's journey that would test his courage, strength, and heart.
# Generated Text: In the small village of Willowbrook, nestled among rolling hills and whispering forests, lived a young farmer named Aiden. Aiden was content with his simple life, tending to the fields and caring for his family. The village was peaceful, and life flowed in harmony with nature. However, a shadow loomed over Willowbrook, an ancient curse that had plagued the land for generations. The soil was barren, and crops failed, threatening the villagers' survival.
#
# One fateful day, a wise old traveler arrived in Willowbrook, bearing tales of a distant land where a mystical artifact could break the curse. Inspired by the traveler's words, Aiden felt a stirring in his heart - a calling to embark on a perilous journey to save his village. With a heavy heart, he bid farewell to his family and set out into the unknown, determined to face dangers and challenges beyond his wildest dreams. And so, Aiden's hero's journey began, his
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 4 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 4 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/lucia.corsan/Prompt-Engineering-Tutorial1/e/PROMPT-16/metadata

# %% [markdown]
# ### **Hands-on Practice**: Implement relevance metric in the evaluation function and run some experiments to test it.

# %%
def get_embedding(text, tokenizer, model):
    """
    Convert text to embedding using the tokenizer and model.
    """
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    # Use the [CLS] token representation for the embedding
    embedding = outputs.last_hidden_state[:, 0, :].numpy()
    return embedding

def calculate_relevance(text, instructions, tokenizer, model):
    """
    Evaluate the relevance of the generated text with respect to the instructions.
    """
    # Get embeddings for both text and instructions
    text_embedding = get_embedding(text, tokenizer, model)
    instructions_embedding = get_embedding(instructions, tokenizer, model)

    # Compute cosine similarity between the embeddings
    similarity = cosine_similarity(text_embedding, instructions_embedding)

    # Return the average similarity as a measure of relevance
    relevance_score = similarity.mean()
    return relevance_score
